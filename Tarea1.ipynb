# %%
import pandas as pd

# %%
baseDatos='https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv'

# %%
CO2=pd.read_csv(baseDatos)
CO2
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                           Russia
# 4                                            Japan
# ..                                             ...
# 213                                     Antarctica
# 214  Saint Helena, Ascension, and Tristan da Cunha
# 215                                           Niue
# 216                       Northern Mariana Islands
# 217                                         Tuvalu
#
#                                             slug             value  \
# 0                                          china  10,773,248,000.0
# 1                                  united-states   5,144,361,000.0
# 2                                          india   2,314,738,000.0
# 3                                         russia   1,848,070,000.0
# ...

# %%
#para eliminar columnas 
byeColumns=['slug','ranking']

# %%
CO2.drop(columns=byeColumns,inplace=True)

# %%
CO2 #1 Keeping. nueva tabla de datos sin la columna slug y ranking
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     date_of_information                   region
# 0             2019 est.  East and Southeast Asia
# ...

# %%
#2. Cambiar nombre de las columnas 
CO2=CO2.rename(columns={"date_of_information": "carbon_date"})

# %%
CO2
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %%
#3. Detectar Leading or Trailing spaces 
CO2.region[CO2.region.str.contains(pat=r'[^\w\s]',regex=True)] #todos los datos son de tipo objeto
# Out:
# Series([], Name: region, dtype: object)

# %%
CO2
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %%
CO2.value=CO2.value.str.strip()

# %%
CO2
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %%
#4. Detectar la presencia de simbolos en data numérica 
CO2.carbon_date.str.contains(pat=r'\D', regex=True)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 213    True
# 214    True
# 215    True
# 216    True
# 217    True
# Name: carbon_date, Length: 218, dtype: bool

# %%
#5 y 6. Asegurarme que no haya espacios entre nombres de columnas 
CO2.columns=CO2.columns.str.replace('', "")

# %%
CO2 #sale igual porque ningun nombre tiene espacios
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %%
#7. Quitar objetos (columna 0) de la columna carbon_date
CO2.carbon_date=CO2.carbon_date.str.split(' ', expand=True)[0] #ponemos [0] para que se quede con lo que esta antes del espacio

# %%
CO2
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0          2019  East and Southeast Asia
# 1          2019            North America
# ...

# %%
#se puso ' ' para que separe las diferentes columnas luego de un espacio
